# %% [markdown]
# <a href="https://colab.research.google.com/github/Namyalg/Topic-Modelling/blob/master/trip_advisor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import gensim

# %%
import nltk

# %%
import io
df = pd.read_csv('/content/dataset.csv')
df
# Out:
#      Reviews__Ratings__Service  ...  Reviews__Ratings__Check in / front desk
# 0                          4.0  ...                                      NaN
# 1                          NaN  ...                                      NaN
# 2                          5.0  ...                                      NaN
# 3                          5.0  ...                                      NaN
# 4                          3.0  ...                                      NaN
# ..                         ...  ...                                      ...
# 228                        3.0  ...                                      3.0
# 229                        3.0  ...                                      4.0
# 230                        5.0  ...                                      5.0
# 231                        NaN  ...                                      NaN
# 232                        NaN  ...                                      NaN
#
# [233 rows x 21 columns]

# %%
df.head()
# Out:
#    Reviews__Ratings__Service  ...  Reviews__Ratings__Check in / front desk
# 0                        4.0  ...                                      NaN
# 1                        NaN  ...                                      NaN
# 2                        5.0  ...                                      NaN
# 3                        5.0  ...                                      NaN
# 4                        3.0  ...                                      NaN
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Reviews__Ratings__Service', 'Reviews__Ratings__Cleanliness',
#        'Reviews__Ratings__Overall', 'Reviews__Ratings__Value',
#        'Reviews__Ratings__Sleep Quality', 'Reviews__Ratings__Rooms',
#        'Reviews__Ratings__Location', 'Reviews__AuthorLocation',
#        'Reviews__Title', 'Reviews__Author', 'Reviews__ReviewID',
#        'Reviews__Content', 'Reviews__Date', 'HotelInfo__Name',
#        'HotelInfo__HotelURL', 'HotelInfo__Price', 'HotelInfo__Address',
#        'HotelInfo__HotelID', 'HotelInfo__ImgURL',
#        'Reviews__Ratings__Business service (e.g., internet access)',
#        'Reviews__Ratings__Check in / front desk'],
#       dtype='object')

# %%
df = df["Reviews__Content"]

# %%
print(len(df))
# Out:
# 233

# %%
for i in (df.head()):
  print(i)
# Out:
# We enjoyed the Best Western Pioneer Square. My husband and I had a room with a king bed and it was clean, quiet, and attractive. Our sons were in a room with twin beds. Their room was in the corner on the main street and they said it was a little noisier and the neon light shone in. But later hotels on the trip made them appreciate this one more. We loved the old wood center staircase. Breakfast was included and everyone was happy with waffles, toast, cereal, and an egg meal. Location was great. We could walk to shops and restaurants as well as transportation. Pike Market was a reasonable walk. We enjoyed the nearby Gold Rush Museum. Very, very happy with our stay. Staff was helpful and knowledgeable.
# ...

# %%
len(df.axes[0]),len(df.axes[1])
# Out:
# (233, 21)

# %%
df.columns
# Out:
# Index(['Reviews__Ratings__Service', 'Reviews__Ratings__Cleanliness',
#        'Reviews__Ratings__Overall', 'Reviews__Ratings__Value',
#        'Reviews__Ratings__Sleep Quality', 'Reviews__Ratings__Rooms',
#        'Reviews__Ratings__Location', 'Reviews__AuthorLocation',
#        'Reviews__Title', 'Reviews__Author', 'Reviews__ReviewID',
#        'Reviews__Content', 'Reviews__Date', 'HotelInfo__Name',
#        'HotelInfo__HotelURL', 'HotelInfo__Price', 'HotelInfo__Address',
#        'HotelInfo__HotelID', 'HotelInfo__ImgURL',
#        'Reviews__Ratings__Business service (e.g., internet access)',
#        'Reviews__Ratings__Check in / front desk'],
#       dtype='object')

# %%
df= df.drop(['Reviews__Ratings__Service', 'Reviews__Ratings__Cleanliness',
       'Reviews__Ratings__Overall', 'Reviews__Ratings__Value',
       'Reviews__Ratings__Sleep Quality', 'Reviews__Ratings__Rooms',
       'Reviews__Ratings__Location', 'Reviews__AuthorLocation',
       'Reviews__Title', 'Reviews__Author', 'Reviews__ReviewID',
       'Reviews__Date', 'HotelInfo__Name',
       'HotelInfo__HotelURL', 'HotelInfo__Price', 'HotelInfo__Address',
       'HotelInfo__HotelID', 'HotelInfo__ImgURL',
       'Reviews__Ratings__Business service (e.g., internet access)',
       'Reviews__Ratings__Check in / front desk'],axis=1)

# %%
df.isnull()
# Out:
#      Reviews__Content
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ..                ...
# 228             False
# 229             False
# 230             False
# 231             False
# 232             False
#
# [233 rows x 1 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#                                       Reviews__Content
# 0    We enjoyed the Best Western Pioneer Square. My...
# 1    Great visit to Seattle thanks to our stay at t...
# 2    Great Location,short walk from Amtrak station,...
# 3    Accommodation in Seattle can be expensive. Thi...
# 4    Very cool old building in a great location. Ch...
# ..                                                 ...
# 228  We had a nice stay in Seattle for two days in ...
# 229  Location, location, location. Leave the car at...
# 230  I love this hotel! The staff was amazing, we h...
# 231  We were booked to stay here for two nights fro...
# 232  We stayed here in late August. This hotel is a...
#
# [233 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233 entries, 0 to 232
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Reviews__Content  233 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %%
df.head(233)
# Out:
#                                       Reviews__Content
# 0    We enjoyed the Best Western Pioneer Square. My...
# 1    Great visit to Seattle thanks to our stay at t...
# 2    Great Location,short walk from Amtrak station,...
# 3    Accommodation in Seattle can be expensive. Thi...
# 4    Very cool old building in a great location. Ch...
# ..                                                 ...
# 228  We had a nice stay in Seattle for two days in ...
# 229  Location, location, location. Leave the car at...
# 230  I love this hotel! The staff was amazing, we h...
# 231  We were booked to stay here for two nights fro...
# 232  We stayed here in late August. This hotel is a...
#
# [233 rows x 1 columns]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from nltk import PorterStemmer
import pandas as pd
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
nltk.download('wordnet')
stemmer = SnowballStemmer("english")
nltk.download("stopwords")
nltk.download("punkt")
stopWords = list(stopwords.words('english'))
print(stopWords)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
import nltk
nltk.download("popular")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from nltk import PorterStemmer
import pandas as pd
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *

stemmer = SnowballStemmer("english")
nltk.download("stopwords")

stopWords = list(stopwords.words('english'))
print(stopWords)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# %%
import string
processed = []
for i in df:
    p = word_tokenize(i)
    p = [word for word in p if word not in stopWords and len(word) > 3]
    p = list(filter(lambda token: token not in string.punctuation, p))
    p = " ".join(p)
    p = lemmatize_stemming(p)
    processed.append(p)
  
print(processed)
# Out:
# ['enjoyed best western pioneer square husband room king clean quiet attractive sons room twin beds their room corner main street said little noisier neon light shone later hotels trip made appreciate loved wood center staircase breakfast included everyone happy waffles toast cereal meal location great could walk shops restaurants well transportation pike market reasonable walk enjoyed nearby gold rush museum very happy stay staff helpful knowledg', 'great visit seattle thanks stay best western pioneer square hotel reasonably priced close everything wanted ferry ride underground tour klondike museum short walk pike market shopping staff amazingly helpful accommodating room clean everything needed breakfast plentiful good before booked read potential issues area honestly area fine fact enjoy historic quaint parts town definitely want stay recommending hotel anyone headed seattl', 'great location short walk amtrak station link game price perfect downtown seattle historic building clean 
# ...

# %%
with open("trip_advisor.txt" , "w") as f:
  for i in processed:
    print(i)
    f.write(i)
    f.write("\n")
# Out:
# enjoyed best western pioneer square husband room king clean quiet attractive sons room twin beds their room corner main street said little noisier neon light shone later hotels trip made appreciate loved wood center staircase breakfast included everyone happy waffles toast cereal meal location great could walk shops restaurants well transportation pike market reasonable walk enjoyed nearby gold rush museum very happy stay staff helpful knowledg
# great visit seattle thanks stay best western pioneer square hotel reasonably priced close everything wanted ferry ride underground tour klondike museum short walk pike market shopping staff amazingly helpful accommodating room clean everything needed breakfast plentiful good before booked read potential issues area honestly area fine fact enjoy historic quaint parts town definitely want stay recommending hotel anyone headed seattl
# ...

# %%
print(len(processed))
# Out:
# 233
